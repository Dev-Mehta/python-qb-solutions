# %% [markdown]
# Write Python code to remove outliers from any given DataFrame
#
# [https://www.storytellingwithdata.com/blog/what-is-a-boxplot](https://www.storytellingwithdata.com/blog/what-is-a-boxplot)

# %%
import pandas as pd
import numpy as np

data = {
    "name": ['William', 'Emma', 'Sofia', 'Markus', 'Edward', 'Thomas', 'Ethan', np.nan, 'Arun', 'Anika', 'Paulo'],
    "region": [np.nan, 'North', 'East', np.nan, 'West', 'West', 'South', np.nan, 'West', 'East', 'South'],
    "sales": [50000, 52000, np.nan, np.nan, 42000, 72000, 49000, np.nan, 67000, 65000, 67000],
    "expenses": [42000, 43000, np.nan, np.nan, 38000, 39000, 42000, np.nan, 39000, 50000, 45000],
}

df = pd.DataFrame(data)
df

# Dropping outliers

# I had to pass numeric_only=True parameter as I have
# newer version of pandas, you may or may not need 
# to pass this parameter.

# You can write df.quantile(0.25), in exams.

# The basic idea is to calculate the first and third quartile,
# A quartile is something that divides the whole dataset into 4 equal parts.
# We then apply `1.5 * IQR` rule to detect the outliers.
# IQR is the difference between the first and third quartile.
# The outliers are the values that are less than `q1 - 1.5 * IQR`
# We give a leeway of 1.5 times the IQR to detect the outliers.
# They are outliers cause even after giving a leeway of 1.5 times the IQR,
# they are still far away from the first and third quartile, creating an imbalance in 
# our data.

def remove_outliers(df, col):
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    return df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
df_no_outliers = remove_outliers(df, 'sales')
print(df_no_outliers.shape)
df_no_outliers
# Out:
# (8, 4)
#        name region    sales  expenses
# 0   William    NaN  50000.0   42000.0
# 1      Emma  North  52000.0   43000.0
# 4    Edward   West  42000.0   38000.0
# 5    Thomas   West  72000.0   39000.0
# 6     Ethan  South  49000.0   42000.0
# 8      Arun   West  67000.0   39000.0
# 9     Anika   East  65000.0   50000.0
# 10    Paulo  South  67000.0   45000.0

# %% [markdown]
# 30. Consider the following data:
#
# ```python
# data = {
#  "A": ["TeamA", "TeamB", "TeamB", "TeamC", "TeamA"],
#  "B": [50, 40, 40, 30, 50],
#  "C": [True, False, False, False, True]
# }
# ```
#
# Convert this to a Pandas DataFrame and remove duplicate rows from it. Reset index values

# %%
data = {
 "A": ["TeamA", "TeamB", "TeamB", "TeamC", "TeamA"],
 "B": [50, 40, 40, 30, 50],
 "C": [True, False, False, False, True]
}
df = pd.DataFrame(data)
df
# Out:
#        A   B      C
# 0  TeamA  50   True
# 1  TeamB  40  False
# 2  TeamB  40  False
# 3  TeamC  30  False
# 4  TeamA  50   True

# %%
df.drop_duplicates(inplace=True)
df.reset_index()
df
# Out:
#        A   B      C
# 0  TeamA  50   True
# 1  TeamB  40  False
# 3  TeamC  30  False

# %% [markdown]
# 31. Consider the following autompg dataset:
# https://raw.githubusercontent.com/Jovita7/Data-Analysis-and-Visualization/main/auto-mpg.csv
# Write Python code to convert it to a DataFrame and remove mpg and cylinders columns from it

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Jovita7/Data-Analysis-and-Visualization/main/auto-mpg.csv")
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.drop(['mpg', 'cylinders'], axis=1,inplace=True) # [Pass column names in list], axis = 1 means delete column, if you specify
# 0 it will search for rows named mpg, cylinders
df
# Out:
#      displacement horsepower  weight  acceleration  model year  origin  \
# 0           307.0        130    3504          12.0          70       1
# 1           350.0        165    3693          11.5          70       1
# 2           318.0        150    3436          11.0          70       1
# 3           304.0        150    3433          12.0          70       1
# 4           302.0        140    3449          10.5          70       1
# ..            ...        ...     ...           ...         ...     ...
# 393         140.0         86    2790          15.6          82       1
# 394          97.0         52    2130          24.6          82       2
# 395         135.0         84    2295          11.6          82       1
# 396         120.0         79    2625          18.6          82       1
# 397         119.0         82    2720          19.4          82       1
#
#                       car name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# ...

# %% [markdown]
# 32 Use the file heights_weights.csv (https://raw.githubusercontent.com/Jovita7/Data-Analysis-and-Visualization/main/heights_weights.csv)
# which contains 10000 non-null values for heights and weights. The Male column shows 1 if the person is a Male and 0 if the person is a Female
# .
# 1. Convert this file into a pandas Data Frame. (0.5 marks)
# 2. Display basic information like memory and data types for this data frame. (0.5 marks)
# 3. Display basic statistics like mean, std, quartiles, etc. for this data frame. (0.5 marks)
# 4. Create a correlation table for the data frame and comment about what kind of correlation is there between Height and Weight.(0.5
# marks)
# 5. Do Height and Weightn any outliers? (1 mark)1 mark)tliers? (1 mark)

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Jovita7/Data-Analysis-and-Visualization/main/heights_weights.csv")
df.info() # memory and data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Height  10000 non-null  float64
#  1   Weight  10000 non-null  float64
#  2   Male    10000 non-null  int64
# dtypes: float64(2), int64(1)
# memory usage: 234.5 KB

# %%
df.describe() # basic statistics
# Out:
#              Height        Weight          Male
# count  10000.000000  10000.000000  10000.000000
# mean      66.367560    161.440357      0.500000
# std        3.847528     32.108439      0.500025
# min       54.263133     64.700127      0.000000
# 25%       63.505620    135.818051      0.000000
# 50%       66.318070    161.212928      0.500000
# 75%       69.174262    187.169525      1.000000
# max       78.998742    269.989699      1.000000

# %%
df.corr() # Corr table 
# Height and weight are positively correlated with corr efficient > 0.9
# Out:
#           Height    Weight      Male
# Height  1.000000  0.924756  0.691072
# Weight  0.924756  1.000000  0.796723
# Male    0.691072  0.796723  1.000000

# %%
q1 = df.quantile(0.25)
q3 = df.quantile(0.75)
iqr = q3 - q1
lower = q1 - 1.5 * iqr
upper = q3 + 1.5 * iqr
outliers = df[(df < lower) | (df > upper)]
outliers.count() # Will give outlier count for all columns
# Out:
# Height    8
# Weight    1
# Male      0
# dtype: int64

# %% [markdown]
# 33 Use the file ipl-matches.csv which contains data of all the IPL matches from year 2008 to 2022. Read this csv file and display the basic
# information like memory and data types for this data frame. Write python code for the following cases:
# 1. List out all matches gone in superover.
# 2. How Many Matches won by Chennai Super Kings at Kolkata.
# 3. In How Many Matches MS Dhoni is Player of Match Vs Mumbai Indians.
# 4. Display list of all matches in which Gujarat Titans won the Toss and Elected to Bat and won the match.
# 5. Display list of all matches won by Gujarat Titans

# %%
df = pd.read_csv("https://raw.githubusercontent.com/kevalsy/python-2/main/ipl-matches.csv")
df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
df[df['SuperOver']=='Y'] # ALl superovers
# Out:
#           ID       City        Date   Season MatchNumber  \
# 114  1254077    Chennai  2021-04-25     2021          20
# 158  1216512  Abu Dhabi  2020-10-18  2020/21          35
# 159  1216517        NaN  2020-10-18  2020/21          36
# 184  1216547        NaN  2020-09-28  2020/21          10
# 192  1216493        NaN  2020-09-20  2020/21           2
# 203  1178426     Mumbai  2019-05-02     2019          51
# 244  1175365      Delhi  2019-03-30     2019          10
# 339  1082625     Rajkot  2017-04-29     2017          35
# 474   829741  Ahmedabad  2015-04-21     2015          18
# 533   729315  Abu Dhabi  2014-04-29     2014          19
# 608   598017  Bangalore  2013-04-16     2013          21
# 621   598004  Hyderabad  2013-04-07     2013           7
# 819   419121    Chennai  2010-03-21  2009/10          16
# 883   392190  Cape Town  2009-04-23     2009          10
#
#                            Team1                        Team2  \
# ...

# %%
df[(df['WinningTeam'] == 'Chennai Super Kings') & (df['City'] == 'Kolkata')]
# Out:
#           ID     City        Date   Season MatchNumber                  Team1  \
# 224  1178404  Kolkata  2019-04-14     2019          29  Kolkata Knight Riders
# 602   598022  Kolkata  2013-04-20     2013          26  Kolkata Knight Riders
# 641   548368  Kolkata  2012-05-14     2012          63  Kolkata Knight Riders
# 827   419113  Kolkata  2010-03-16  2009/10           8  Kolkata Knight Riders
# 908   336025  Kolkata  2008-05-18  2007/08          41  Kolkata Knight Riders
#
#                    Team2         Venue             TossWinner TossDecision  \
# 224  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 602  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
# 641  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 827  Chennai Super Kings  Eden Gardens    Chennai Super Kings          bat
# 908  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
#
# ...

# %%
df[(df['Player_of_Match'] == 'MS Dhoni') & ((df['Team1'] == 'Mumbai Indians')|(df['Team2'] == 'Mumbai Indians'))]
# Out:
#          ID       City        Date Season        MatchNumber  \
# 630  548379  Bangalore  2012-05-23   2012  Elimination Final
#
#                    Team1           Team2                  Venue  \
# 630  Chennai Super Kings  Mumbai Indians  M Chinnaswamy Stadium
#
#          TossWinner TossDecision SuperOver          WinningTeam WonBy  Margin  \
# 630  Mumbai Indians        field         N  Chennai Super Kings  Runs    38.0
#
#     method Player_of_Match                                       Team1Players  \
# 630    NaN        MS Dhoni  ['M Vijay', 'MEK Hussey', 'SK Raina', 'S Badri...
#
#                                           Team2Players    Umpire1  \
# 630  ['SR Tendulkar', 'DR Smith', 'RG Sharma', 'KD ...  BF Bowden
#
#              Umpire2
# 630  HDPK Dharmasena

# %%
df[(df['TossDecision'] == 'bat') & (df['TossWinner'] == 'Gujarat Titans') & (df['WinningTeam'] == 'Gujarat Titans')]
# Out:
#          ID         City        Date Season MatchNumber           Team1  \
# 17  1304103         Pune  2022-05-10   2022          57  Gujarat Titans
# 39  1304081  Navi Mumbai  2022-04-23   2022          35  Gujarat Titans
#
#                     Team2                                          Venue  \
# 17   Lucknow Super Giants  Maharashtra Cricket Association Stadium, Pune
# 39  Kolkata Knight Riders             Dr DY Patil Sports Academy, Mumbai
#
#         TossWinner TossDecision SuperOver     WinningTeam WonBy  Margin  \
# 17  Gujarat Titans          bat         N  Gujarat Titans  Runs    62.0
# 39  Gujarat Titans          bat         N  Gujarat Titans  Runs     8.0
#
#    method Player_of_Match                                       Team1Players  \
# 17    NaN    Shubman Gill  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...
# 39    NaN     Rashid Khan  ['WP Saha', 'Shubman Gill', 'HH Pandya', 'DA M...
#
# ...

# %%
df[df['WinningTeam'] == 'Gujarat Titans']
# Out:
#          ID         City        Date Season  MatchNumber  \
# 0   1312200    Ahmedabad  2022-05-29   2022        Final
# 3   1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 12  1304108       Mumbai  2022-05-15   2022           62
# 17  1304103         Pune  2022-05-10   2022           57
# 31  1304089       Mumbai  2022-04-30   2022           43
# 34  1304086       Mumbai  2022-04-27   2022           40
# 39  1304081  Navi Mumbai  2022-04-23   2022           35
# 45  1304075         Pune  2022-04-17   2022           29
# 50  1304070       Mumbai  2022-04-14   2022           24
# 58  1304062       Mumbai  2022-04-08   2022           16
# 64  1304056         Pune  2022-04-02   2022           10
# 70  1304050       Mumbai  2022-03-28   2022            4
#
#                           Team1                  Team2  \
# 0              Rajasthan Royals         Gujarat Titans
# 3              Rajasthan Royals         Gujarat Titans
# ...

# %% [markdown]
# 34 Use the file spotify.csv
#
# 1. Convert this file into a pandas Data Frame. (0.5 marks)
# 2. Display basic c information like memory and data types for this data frame. (0.5 marks)
# 3. Display basic statistics like mean, std, quartiles, etc. for this data frame.(0.5 marks)
# 4. Create a correlation table for the data frame and comment about what kind of correlaƟon is there between danceability and energy (0.5
# marks)
# 5. Display first five rows for this data frame.(0.5 marks)
# 6. Display last five rows for this data frame. (0.5 marks)
# 7. Display the rows between 15 to 39 for this data frame. (0.5 marks)
# 8. Display the data only for last five rows and last five columns for this data frame. (0.5 marks)
# 9. Display the shape for this data frame. (0.5 marks)
# 10. Display the sum of NULL values for all the columns. (0.5 marks)
# 11. Remove first 3 columns from this Data Frame. (0.5 marks)
# 12. Remove first 10 rows from this Data Frame. (0.5 marks)
# 13. After removing first 3 columns and first 10 rows from this data frame find outliers for the column popularity. (1 marks)
# 14. After removing first 3 columns and first 10 rows from this data frame remove outliers for the column energy then display the data frame.
# (1 marks)
# 15. Display cross tabulaƟon between Ɵme_signature and track_genre for actual Data Frame. (1 marks)ta Frame. (1 marks)

# %%
url = "https://drive.google.com/file/d/1wkl0Z0FNe8nEjEsx3lBmO3vIg7pihk6i/view"
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df = pd.read_csv(url)
df.info() # basic info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %%
df.describe() # basic statistics
# Out:
#           Unnamed: 0     popularity   duration_ms   danceability  \
# count  114000.000000  114000.000000  1.140000e+05  114000.000000
# mean    56999.500000      33.238535  2.280292e+05       0.566800
# std     32909.109681      22.305078  1.072977e+05       0.173542
# min         0.000000       0.000000  0.000000e+00       0.000000
# 25%     28499.750000      17.000000  1.740660e+05       0.456000
# 50%     56999.500000      35.000000  2.129060e+05       0.580000
# 75%     85499.250000      50.000000  2.615060e+05       0.695000
# max    113999.000000     100.000000  5.237295e+06       0.985000
#
#               energy            key       loudness           mode  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        0.641383       5.309140      -8.258960       0.637553
# std         0.251529       3.559987       5.029337       0.480709
# min         0.000000       0.000000     -49.531000       0.000000
# ...

# %%
df.corr(numeric_only=True) # corr table
# Danceability and energy are positively correlated but it is not a good correlation as corr value is just 0.13
# Out:
#                   Unnamed: 0  popularity  duration_ms  explicit  danceability  \
# Unnamed: 0          1.000000    0.032142    -0.032743 -0.054736      0.003444
# popularity          0.032142    1.000000    -0.007101  0.044082      0.035448
# duration_ms        -0.032743   -0.007101     1.000000 -0.065263     -0.073426
# explicit           -0.054736    0.044082    -0.065263  1.000000      0.122507
# danceability        0.003444    0.035448    -0.073426  0.122507      1.000000
# energy             -0.055994    0.001056     0.058523  0.096955      0.134325
# key                -0.005520   -0.003853     0.008114  0.004484      0.036469
# loudness           -0.027307    0.050423    -0.003470  0.108588      0.259077
# mode                0.005107   -0.013931    -0.035556 -0.037212     -0.069219
# speechiness        -0.084952   -0.044927    -0.062600  0.307952      0.108626
# acousticness        0.076840   -0.025472    -0.103788 -0.094403     -0.171533
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0                track_id           artists  \
# 113995      113995  2C3TZjDRiAzdyViavDJ217     Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw     Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX     Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs  Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5     Cesária Evora
#
#                                                album_name  \
# 113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  #mindfulness - Soft Rain for Mindful Meditatio...
# 113997                                            Best Of
# 113998                                  Change Your World
# 113999                                     Miss Perfumado
#
#                  track_name  popularity  duration_ms  explicit  danceability  \
# 113995  Sleep My Little Boy          21       384999     False         0.172
# 113996     Water Into Light          22       385000     False         0.174
# ...

# %%
df.loc[15:39]
# Out:
#     Unnamed: 0                track_id                               artists  \
# 15          15  1KHdq8NK9QxnGjdXb55NiG                           Landon Pigg
# 16          16  6xKeQgzfjixSUld14qUezm                  Andrew Foy;Renee Foy
# 17          17  4Yo0igmcoNyat1secaH0OD                  Andrew Foy;Renee Foy
# 18          18  2qLMf6TuEC3ruGJg4SMMN6             Jason Mraz;Colbie Caillat
# 19          19  6CgNoAbFJ4Q4Id4EjtbXlC               Boyce Avenue;Bea Miller
# 20          20  3S0OXQeoh0w6AY8WQVckRW                            Jason Mraz
# 21          21  210JCw2LbYD4YIs8GiZ9iP            Boyce Avenue;Jennel Garcia
# 22          22  5TvE3pk05pyFIGdSY9j4DJ  A Great Big World;Christina Aguilera
# 23          23  0BUuuEvNa5T4lMaewyiudB                            Jason Mraz
# 24          24  3Hn3LfhrQOaKihdCibJsTs                            Jason Mraz
# 25          25  6D33wCKzWtNEgOovgeVJ7r                            Jason Mraz
# ...

# %%
df.tail(5).iloc[:, -5:] # Display the data only for last five rows and last five columns for this data frame. (
# Out:
#         liveness  valence    tempo  time_signature  track_genre
# 113995    0.0863   0.0339  125.995               5  world-music
# 113996    0.1050   0.0350   85.239               4  world-music
# 113997    0.0839   0.7430  132.378               4  world-music
# 113998    0.2700   0.4130  135.960               4  world-music
# 113999    0.0893   0.7080   79.198               4  world-music

# %%
df.shape
# Out:
# (114000, 21)

# %%
df.isnull().sum() # Sum of null values
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
df.iloc[:,3:] # Removing first 3 cols
# Out:
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                 Hold On
# ...                                                   ...
# 113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  #mindfulness - Soft Rain for Mindful Meditatio...
# 113997                                            Best Of
# 113998                                  Change Your World
# 113999                                     Miss Perfumado
#
#                         track_name  popularity  duration_ms  explicit  \
# 0                           Comedy          73       230666     False
# 1                 Ghost - Acoustic          55       149610     False
# ...

# %%
df.iloc[10:] # Remove first 10 rows
# Out:
#         Unnamed: 0                track_id                   artists  \
# 10              10  4mzP5mHkRvGxdhdGdAH7EJ              Zack Tabudlo
# 11              11  5ivF4eQBqJiVL5IAE9jRyl                Jason Mraz
# 12              12  4ptDJbJl35d7gQfeNteBwp                  Dan Berk
# 13              13  0X9MxHR1rTkEHDjp95F2OO             Anna Hamilton
# 14              14  4LbWtBkN82ZRhz9jqzgrb3  Chord Overstreet;Deepend
# ...            ...                     ...                       ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217             Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw             Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX             Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs          Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5             Cesária Evora
#
#                                                album_name  \
# 10                                                Episode
# ...

# %%
# After removing first 3 columns and first 10 rows from this data frame find outliers for the column popularity.
df_pop = df.iloc[10:, 3:]
q1 = df_pop.popularity.quantile(0.25)
q3 = df_pop.popularity.quantile(0.75)
iqr = q3 - q1
lower = q1 - 1.5 * iqr
upper = q3 + 1.5 * iqr
outliers = df_pop.where((df_pop['popularity'] < lower) | (df_pop['popularity'] > upper))
outliers.popularity.count()
# Out:
# 2

# %%
# After removing first 3 columns and first 10 rows from this data frame remove outliers for the column energy then display the data frame. 
df_energy = df.iloc[10:, 3:]
q1 = df_energy.energy.quantile(0.25)
q3 = df_energy.energy.quantile(0.75)
iqr = q3 - q1
lower = q1 - 1.5 * iqr
upper = q3 + 1.5 * iqr
np.where((df_energy['energy'] < lower) | (df_energy['energy'] > upper)) # There seems to be no outliers in energy column
# Out:
# (array([], dtype=int64),)

# %%
pd.crosstab(df.time_signature,df.track_genre)
# Out:
# track_genre     acoustic  afrobeat  alt-rock  alternative  ambient  anime  \
# time_signature
# 0                      0         0         1            0        3      0
# 1                      9         5         1            2       39      7
# 3                    101        52        56           64      264     63
# 4                    877       930       940          922      648    923
# 5                     13        13         2           12       46      7
#
# track_genre     black-metal  bluegrass  blues  brazil  ...  spanish  study  \
# time_signature                                         ...
# 0                         0          0      0       0  ...        0      0
# 1                        20          5      6       5  ...        2      6
# 3                       129         80     97      42  ...       55     49
# 4                       838        909    894     939  ...      937    934
# ...

# %% [markdown]
# 35 Dataset link: https://drive.google.com/file/d/12RPDu4blghWiY02rsbnQnlkohBPjMmPo/view?usp=drive_link
# 1. Load the dataset into a pandas DataFrame (data_result.csv) and answer the following questions.
# 2. View the first few rows of the dataset
# 3. Check the shape of the dataset
# 4. View the first last rows of the dataset
# 5. Get summary statistics of numerical columns
# 6. Get summary statistics of numerical columns with 0.58 and 0.87 percentiles
# 7. Get summary statistics of all types of columns
# 8. Information of all columns
# 9. Check for missing values
# 10. Removing duplicates if duplicates
# 11. List out female students who have greater than 7 spi in all semesters.
# 12. Find number of students those who have greater than 8 spi in all 5 semesters

# %%
url = "https://drive.google.com/file/d/12RPDu4blghWiY02rsbnQnlkohBPjMmPo/view?usp=drive_link"
url = 'https://drive.google.com/uc?id=' + url.split('/')[-2]

df = pd.read_csv(url)
print("First few")
print(df.head())
print("Shape")
print(df.shape)
print("Last few")
print(df.tail())
# Out:
# First few
#     1st   2nd   3rd   4th   5th  College Code  Gender  Roll no.  Subject Code
# 0  8.11  7.68  7.11  7.43  8.18           115  Female     17020            16
# 1  6.48  5.90  4.15  4.29  4.96           115    Male     17021            16
# 2  8.41  8.24  7.52  8.25  7.75           115  Female     17022            16
# 3  7.33  6.83  6.33  6.79  6.89           115    Male     17023            16
# 4  7.89  7.34  7.22  7.32  7.46           115    Male     17024            16
# Shape
# (46, 9)
# Last few
#      1st   2nd   3rd   4th   5th  College Code Gender  Roll no.  Subject Code
# 41  6.30  6.24  5.85  6.36  7.00           115   Male     17061            16
# 42  7.78  6.93  7.44  7.86  8.21           115   Male     17062            16
# 43  8.22  6.66  7.07  7.29  7.61           115   Male     17063            16
# 44  7.67  7.07  7.04  7.07  6.93           115   Male     17064            16
# ...

# %%
df.describe() # Statistical Analysis
# Out:
#              1st        2nd        3rd        4th        5th  College Code  \
# count  46.000000  46.000000  46.000000  46.000000  46.000000          46.0
# mean    7.397609   6.930217   6.703043   7.237826   7.527609         115.0
# std     0.798391   0.910425   0.917324   1.057981   0.967963           0.0
# min     5.670000   4.280000   4.150000   4.290000   4.860000         115.0
# 25%     6.787500   6.350000   6.217500   6.650000   6.890000         115.0
# 50%     7.440000   6.810000   7.000000   7.290000   7.625000         115.0
# 75%     8.040000   7.590000   7.322500   7.890000   8.210000         115.0
# max     8.890000   8.720000   8.370000   9.250000   9.000000         115.0
#
#            Roll no.  Subject Code
# count     46.000000          46.0
# mean   17042.500000          16.0
# std       13.422618           0.0
# min    17020.000000          16.0
# 25%    17031.250000          16.0
# 50%    17042.500000          16.0
# 75%    17053.750000          16.0
# ...

# %%
df.describe(percentiles=[.25,0.58,0.87,.5,.75]) # Statistical Analysis with 0.58 and 0.87 percentile
# Out:
#              1st        2nd        3rd        4th        5th  College Code  \
# count  46.000000  46.000000  46.000000  46.000000  46.000000          46.0
# mean    7.397609   6.930217   6.703043   7.237826   7.527609         115.0
# std     0.798391   0.910425   0.917324   1.057981   0.967963           0.0
# min     5.670000   4.280000   4.150000   4.290000   4.860000         115.0
# 25%     6.787500   6.350000   6.217500   6.650000   6.890000         115.0
# 50%     7.440000   6.810000   7.000000   7.290000   7.625000         115.0
# 58%     7.787000   6.944000   7.114000   7.647000   7.860000         115.0
# 75%     8.040000   7.590000   7.322500   7.890000   8.210000         115.0
# 87%     8.220000   8.000000   7.530500   8.336500   8.531500         115.0
# max     8.890000   8.720000   8.370000   9.250000   9.000000         115.0
#
#            Roll no.  Subject Code
# count     46.000000          46.0
# mean   17042.500000          16.0
# std       13.422618           0.0
# ...

# %%
df.describe(include='all') # ALl columns statistical analysis
# Out:
#               1st        2nd        3rd        4th        5th  College Code  \
# count   46.000000  46.000000  46.000000  46.000000  46.000000          46.0
# unique        NaN        NaN        NaN        NaN        NaN           NaN
# top           NaN        NaN        NaN        NaN        NaN           NaN
# freq          NaN        NaN        NaN        NaN        NaN           NaN
# mean     7.397609   6.930217   6.703043   7.237826   7.527609         115.0
# std      0.798391   0.910425   0.917324   1.057981   0.967963           0.0
# min      5.670000   4.280000   4.150000   4.290000   4.860000         115.0
# 25%      6.787500   6.350000   6.217500   6.650000   6.890000         115.0
# 50%      7.440000   6.810000   7.000000   7.290000   7.625000         115.0
# 75%      8.040000   7.590000   7.322500   7.890000   8.210000         115.0
# max      8.890000   8.720000   8.370000   9.250000   9.000000         115.0
#
#        Gender      Roll no.  Subject Code
# ...

# %%
df.info() # Info of all columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   1st           46 non-null     float64
#  1   2nd           46 non-null     float64
#  2   3rd           46 non-null     float64
#  3   4th           46 non-null     float64
#  4   5th           46 non-null     float64
#  5   College Code  46 non-null     int64
#  6   Gender        46 non-null     object
#  7   Roll no.      46 non-null     int64
#  8   Subject Code  46 non-null     int64
# dtypes: float64(5), int64(3), object(1)
# memory usage: 3.4+ KB

# %%
df.isna().sum() # Count of missing values in each column
# Out:
# 1st             0
# 2nd             0
# 3rd             0
# 4th             0
# 5th             0
# College Code    0
# Gender          0
# Roll no.        0
# Subject Code    0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#      1st   2nd   3rd   4th   5th  College Code  Gender  Roll no.  Subject Code
# 0   8.11  7.68  7.11  7.43  8.18           115  Female     17020            16
# 1   6.48  5.90  4.15  4.29  4.96           115    Male     17021            16
# 2   8.41  8.24  7.52  8.25  7.75           115  Female     17022            16
# 3   7.33  6.83  6.33  6.79  6.89           115    Male     17023            16
# 4   7.89  7.34  7.22  7.32  7.46           115    Male     17024            16
# 5   7.33  6.72  6.48  6.50  7.39           115    Male     17025            16
# 6   7.15  6.72  6.89  6.86  7.64           115    Male     17026            16
# 7   6.74  6.38  4.93  5.64  6.75           115    Male     17027            16
# 8   7.89  7.45  6.96  7.71  8.00           115  Female     17028            16
# 9   7.30  6.34  6.30  6.61  6.18           115    Male     17029            16
# 10  8.00  7.90  7.52  7.64  8.11           115    Male     17030            16
# ...

# %%
df['average'] = df.iloc[:,:5].sum(axis=1)/5

# %%
df[(df['Gender'] == 'Female') & (df['average'] > 7)]
# Out:
#      1st   2nd   3rd   4th   5th  College Code  Gender  Roll no.  \
# 0   8.11  7.68  7.11  7.43  8.18           115  Female     17020
# 2   8.41  8.24  7.52  8.25  7.75           115  Female     17022
# 8   7.89  7.45  6.96  7.71  8.00           115  Female     17028
# 21  8.33  8.72  7.81  8.04  8.93           115  Female     17041
# 25  7.89  6.69  7.15  8.43  8.36           115  Female     17045
# 31  8.89  8.31  7.30  9.25  8.50           115  Female     17051
# 36  7.85  6.90  7.04  7.82  8.39           115  Female     17056
#
#     Subject Code  average
# 0             16    7.702
# 2             16    8.034
# 8             16    7.602
# 21            16    8.366
# 25            16    7.704
# 31            16    8.450
# 36            16    7.600

# %%
df[(df['average'] > 8)]
# Out:
#      1st   2nd   3rd   4th   5th  College Code  Gender  Roll no.  \
# 2   8.41  8.24  7.52  8.25  7.75           115  Female     17022
# 21  8.33  8.72  7.81  8.04  8.93           115  Female     17041
# 22  7.96  7.93  7.78  8.21  8.21           115    Male     17042
# 27  8.22  8.17  8.37  9.04  9.00           115    Male     17047
# 31  8.89  8.31  7.30  9.25  8.50           115  Female     17051
# 33  8.30  8.38  7.63  7.93  8.75           115    Male     17053
# 35  7.44  7.97  7.78  8.64  8.71           115    Male     17055
# 39  8.19  7.66  7.48  8.68  8.89           115    Male     17059
#
#     Subject Code  average
# 2             16    8.034
# 21            16    8.366
# 22            16    8.018
# 27            16    8.560
# 31            16    8.450
# 33            16    8.198
# 35            16    8.108
# 39            16    8.180

# %% [markdown]
# 36 https://drive.google.com/file/d/1jeuTUVJibNBcQlAyzgLo7XazqXC58cnA/view?usp=drive_link
#
# Use the file movies.csv which contains 1629 rows and 18 columns. Read this csv file and display the basic information like memory and data
# types for this data frame.
# Write python code for the following case
# s:
#
# 1.List out Movies Released in Year 2019.
# 2.How Many Movies are having IMDti RaƟng > 7 (Display Number of Movies) .
# 3.List out the Movies wtith ‘Ɵtle’ and ‘story’ whose IMDB Votes > 2000 0.
# 4.List out Movies Released in Year 2018, Display only Movie Title with Release Date of Year 2018 Movi es.
# 5.Display only Movie Title with its Wikipedia Link.

# %%
url = 'https://drive.google.com/file/d/1jeuTUVJibNBcQlAyzgLo7XazqXC58cnA/view?usp=drive_link'
url = 'https://drive.google.com/uc?id=' + url.split('/')[-2]

df = pd.read_csv(url)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
df[df['year_of_release'] == 2019] # Movies released in 2019
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 6                            Fraud Saiyaan   tt5013008
# ...                                    ...         ...
# 76                       Commando 3 (film)   tt8983168
# 77                              Mardaani 2   tt5668770
# 78                               Dabangg 3   tt7059844
# 79                              Good Newwz   tt8504014
# 1627                                 Daaka  tt10833860
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
df[df['imdb_rating'] > 7].shape[0] # Movies having IMDB rating > 7
# Out:
# 331

# %%
df[df['imdb_votes'] > 2000][['title_y', 'story']]
# Out:
#                                title_y  \
# 0             Uri: The Surgical Strike
# 2        The Accidental Prime Minister
# 8     Manikarnika: The Queen of Jhansi
# 9                            Thackeray
# 11                           Gully Boy
# ...                                ...
# 1607              Nayak: The Real Hero
# 1608                        One 2 Ka 4
# 1616         Rehnaa Hai Terre Dil Mein
# 1621  Tum Bin...: Love Will Find a Way
# 1628                          Humsafar
#
#                                                   story
# 0     Divided over five chapters  the film chronicle...
# 2     Based on the memoir by Indian policy analyst S...
# 8     Manikarnika born in Varanasi when Dixt a minis...
# 9     Balasaheb Thackrey works as a cartoonist for a...
# 11    Gully Boy is a film about a 22-year-old boy "M...
# ...                                                 ...
# 1607  Employed as a camera-man at a popular televisi...
# ...

# %%
df[df['year_of_release'] == 2018][['title_y']]
# Out:
#                         title_y
# 4               Evening Shadows
# 5                          Soni
# 16      Mard Ko Dard Nahin Hota
# 17                        Hamid
# 20    Mere Pyare Prime Minister
# ...                         ...
# 156                Rajma Chawal
# 157                        Zero
# 158                      Simmba
# 166          Thugs of Hindostan
# 1626            Sabse Bada Sukh
#
# [79 rows x 1 columns]

# %%
df[['title_y', 'wiki_link']]
# Out:
#                             title_y  \
# 0          Uri: The Surgical Strike
# 1                     Battalion 609
# 2     The Accidental Prime Minister
# 3                   Why Cheat India
# 4                   Evening Shadows
# ...                             ...
# 1624          Tera Mera Saath Rahen
# 1625           Yeh Zindagi Ka Safar
# 1626                Sabse Bada Sukh
# 1627                          Daaka
# 1628                       Humsafar
#
#                                               wiki_link
# 0     https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1           https://en.wikipedia.org/wiki/Battalion_609
# 2     https://en.wikipedia.org/wiki/The_Accidental_P...
# 3         https://en.wikipedia.org/wiki/Why_Cheat_India
# 4         https://en.wikipedia.org/wiki/Evening_Shadows
# ...                                                 ...
# 1624  https://en.wikipedia.org/wiki/Tera_Mera_Saath_...
# 1625  https://en.wikipedia.org/wiki/Yeh_Zindagi_Ka_S...
# ...
